# %%
import pandas as pd

# %% [markdown]
# ### ZRI Time Series
# https://www.zillow.com/research/methodology-zillow-rent-index-2019-25172/

# %%
zri_time = pd.read_csv('Metro_Zri_AllHomesPlusMultifamily.csv', encoding = "ISO-8859-1")
print(zri_time.shape)
zri_time.head()
# Out:
# (779, 115)
#    RegionID                          RegionName  SizeRank  2010-09  2010-10  \
# 0    102001                       United States         0   1310.0   1310.0
# 1    394913                        New York, NY         1   1680.0   1680.0
# 2    753899  Los Angeles-Long Beach-Anaheim, CA         2   2220.0   2220.0
# 3    394463                         Chicago, IL         3   1450.0   1450.0
# 4    394514               Dallas-Fort Worth, TX         4   1050.0   1060.0
#
#    2010-11  2010-12  2011-01  2011-02  2011-03  ...  2019-03  2019-04  \
# 0   1310.0   1310.0   1300.0   1300.0   1290.0  ...   1570.0   1570.0
# 1   1680.0   1680.0   1680.0   1670.0   1660.0  ...   2260.0   2260.0
# 2   2210.0   2200.0   2190.0   2170.0   2160.0  ...   2590.0   2580.0
# 3   1450.0   1450.0   1430.0   1420.0   1410.0  ...   1570.0   1580.0
# 4   1070.0   1080.0   1070.0   1070.0   1060.0  ...   1430.0   1430.0
#
#    2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# ...

# %%
condTN = zri_time['RegionName'].str.contains('Sevierville, TN')

# %%
zri_time_TN = zri_time[condTN]
zri_time_TN
# Out:
#      RegionID       RegionName  SizeRank  2010-09  2010-10  2010-11  2010-12  \
# 374    395086  Sevierville, TN       374   1000.0   1010.0   1010.0   1020.0
#
#      2011-01  2011-02  2011-03  ...  2019-03  2019-04  2019-05  2019-06  \
# 374   1020.0      NaN      NaN  ...   1230.0   1210.0   1210.0   1210.0
#
#      2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# 374   1210.0   1210.0   1210.0      NaN   1190.0   1200.0
#
# [1 rows x 115 columns]

# %% [markdown]
# ### Median Rent Price SFR

# %%
medRentPrice = pd.read_csv('Metro_Zri_AllHomesPlusMultifamily.csv', encoding = "ISO-8859-1")
print(medRentPrice.shape)
medRentPrice.tail()
# Out:
# (779, 115)
#      RegionID     RegionName  SizeRank  2010-09  2010-10  2010-11  2010-12  \
# 774    394330    Andrews, TX       774   1110.0   1120.0   1110.0   1100.0
# 775    753929     Zapata, TX       775      NaN      NaN      NaN      NaN
# 776    394767     Lamesa, TX       776   1000.0      NaN   1020.0   1030.0
# 777    753874      Craig, CO       777      NaN   1250.0      NaN   1250.0
# 778    394743  Ketchikan, AK       778      NaN      NaN      NaN      NaN
#
#      2011-01  2011-02  2011-03  ...  2019-03  2019-04  2019-05  2019-06  \
# 774   1100.0   1090.0   1090.0  ...   1270.0   1280.0   1290.0   1300.0
# 775      NaN      NaN      NaN  ...   1010.0   1000.0    990.0    990.0
# 776   1030.0   1020.0   1040.0  ...      NaN   1100.0   1120.0   1130.0
# 777   1260.0   1250.0   1230.0  ...   1580.0   1600.0   1630.0   1640.0
# 778   1490.0      NaN   1550.0  ...   1450.0   1450.0   1460.0   1470.0
#
#      2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# ...

# %%
condTN2 = medRentPrice['RegionName'].str.contains('TN')
medRentPrice_TN = medRentPrice[condTN2]
medRentPrice_TN
# Out:
#      RegionID        RegionName  SizeRank  2010-09  2010-10  2010-11  2010-12  \
# 37     394902     Nashville, TN        37   1120.0   1130.0   1120.0   1110.0
# 41     394849       Memphis, TN        41    980.0    980.0    980.0    980.0
# 63     394753     Knoxville, TN        63    910.0    920.0    930.0    940.0
# 97     394460   Chattanooga, TN        97    950.0    960.0    960.0    960.0
# 152    394747     Kingsport, TN       152    870.0    870.0    870.0    870.0
# 168    394471   Clarksville, TN       168    850.0    850.0    840.0    830.0
# 209    394726  Johnson City, TN       209    860.0    860.0    850.0    850.0
# 298    394712       Jackson, TN       298    790.0    810.0    810.0    820.0
# 322    394474     Cleveland, TN       322    880.0    890.0    890.0    890.0
# 327    394880    Morristown, TN       327    820.0    830.0    830.0    830.0
# 340    394495    Cookeville, TN       340    890.0    890.0    890.0    890.0
# ...

# %%
zipMed = pd.read_csv('Neighborhood_MedianRentalPrice_AllHomes.csv', encoding = "ISO-8859-1")
print(zipMed.shape)
zipMed.head()
# Out:
# (782, 125)
#           RegionName         City State                           Metro  \
# 0   Northeast Dallas       Dallas    TX     Dallas-Fort Worth-Arlington
# 1           Maryvale      Phoenix    AZ         Phoenix-Mesa-Scottsdale
# 2           Paradise    Las Vegas    NV    Las Vegas-Henderson-Paradise
# 3    Upper West Side     New York    NY     New York-Newark-Jersey City
# 4  South Los Angeles  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
#
#            CountyName  SizeRank  2010-02  2010-03  2010-04  2010-05  ...  \
# 0       Dallas County         1      NaN      NaN      NaN      NaN  ...
# 1     Maricopa County         2      NaN      NaN      NaN    890.0  ...
# 2        Clark County         3      NaN      NaN      NaN      NaN  ...
# 3     New York County         4   2875.0   2825.0   3000.0   3050.0  ...
# 4  Los Angeles County         5      NaN      NaN      NaN      NaN  ...
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  \
# ...

# %%
regString = zipMed['RegionName'].apply(str)
regString.shape
# Out:
# (782,)

# %%
pd.options.display.max_rows = 70

condStr = zipMed['State'] == 'TN'
zipMed[condStr]
# Out:
#                           RegionName      City State  \
# 36   East Memphis-Colonial-Yorkshire   Memphis    TN
# 48             White Haven-Coro Lake   Memphis    TN
# 76                   Cordova-Appling   Memphis    TN
# 87     Hickory Ridge-South Riverdale   Memphis    TN
# 94                           Midtown   Memphis    TN
# 122                          Raleigh   Memphis    TN
# 182        River Oaks-Kirby-Balmoral   Memphis    TN
# 189         Parkway Village-Oakhaven   Memphis    TN
# 227            Shelby Forest-Frayser   Memphis    TN
# 233        Berclair-Highland Heights   Memphis    TN
# 630                     West Harpeth  Franklin    TN
#
#                                           Metro         CountyName  SizeRank  \
# 36                                      Memphis      Shelby County        37
# 48                                      Memphis      Shelby County        49
# 76                                      Memphis      Shelby County        77
# ...

# %%
condTN3 = zipMed['RegionName']
zipMed_gat = zipMed[condTN3]
zipMed_gat
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-6673bf86a810> in <module>
#       1 condTN3 = zipMed['RegionName']
# ----> 2 zipMed_gat = zipMed[condTN3]
#       3 zipMed_gat
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# ...

# %%
df = medRentPrice

# %%
df[cols[condYear]].head(2)
# Out:
#    2011-01  2011-02  2011-03  2011-04  2011-05  2011-06  2011-07  2011-08  \
# 0   1300.0   1300.0   1290.0   1290.0   1290.0   1300.0   1300.0   1310.0
# 1   1680.0   1670.0   1660.0   1660.0   1660.0   1660.0   1670.0   1680.0
#
#    2011-09  2011-10  2011-11  2011-12
# 0   1310.0   1310.0   1300.0   1300.0
# 1   1690.0   1700.0   1700.0   1700.0

# %%
df[cols[condYear]].mean(axis=1)
# Out:
# 0      1300.000000
# 1      1677.500000
# 2      2161.666667
# 3      1410.833333
# 4      1063.333333
#           ...
# 774    1103.333333
# 775            NaN
# 776    1040.833333
# 777    1216.666667
# 778    1544.545455
# Length: 779, dtype: float64

# %%
#df11['Mean'] = df11.mean(axis=1)

# %%
def meanMonths(df):
    cols = df.columns
    years = ['2010', '2011', '2012', '2013', '2014', 
             '2015', '2016', '2017', '2018', '2019']
    meanPerYear = {}
    for year in years:
        cond = df.columns.str.contains(year)
        regionMeans = df[cols[condYear]].mean(axis=1)
        meanPerYear.update({year: regionMeans})

# %%
d = meanMonths(df)
len(d)
# Out:
# 10

# %%
# WORKS

def getSevTN(df):
    condition = df['RegionName'] == ('Sevierville, TN')
    return df[condition]

# %%
getSevTN(df)
# Out:
#      RegionID       RegionName  SizeRank  2010-09  2010-10  2010-11  2010-12  \
# 374    395086  Sevierville, TN       374   1000.0   1010.0   1010.0   1020.0
#
#      2011-01  2011-02  2011-03  ...  2019-03  2019-04  2019-05  2019-06  \
# 374   1020.0      NaN      NaN  ...   1230.0   1210.0   1210.0   1210.0
#
#      2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# 374   1210.0   1210.0   1210.0      NaN   1190.0   1200.0
#
# [1 rows x 115 columns]
